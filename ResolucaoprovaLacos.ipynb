# %%
import random
secret = random.randint(1,100)
resp = 0
x = 0
vidas = 10

while resp != secret:

  resp = int(input("Digite um numero de 1 a 100"))
  if resp <=0 or resp > 100:
    print('apenas numeros de 1 a 100 sao validos, voce esta eliminado')
    break


  if resp > secret:
    print("o numero esta abaixo")
    calc = resp - secret
    if calc <= 5:
      print('voce esta quente')
    elif calc > 5 and calc <= 10:
      print('voce esta morno')
    elif calc > 10 and calc <= 20:
      print('voce esta frio')
    elif calc > 20:
      print('voce esta congelado')

  if resp < secret:
    print("o numero esta acima")
    calc = secret - resp
    if calc <= 5:
      print('voce esta quente')
    elif calc > 5 and calc <= 10:
      print('voce esta morno')
    elif calc > 10 and calc <= 20:
      print('voce esta frio')
    elif calc > 20:
      print('voce esta congelado')
  x = x + 1
  vidas = vidas - 1
  print(f'voce tem {vidas} vidas')
  if vidas == 0:
    print('voce perdeu')
    break
    5
if resp == secret:
   print('parabens voce acertou')

print(f'voce tentou {x} vezes')
# Out:
# Digite um numero de 1 a 10054
# o numero esta abaixo
# voce esta congelado
# voce tem 9 vidas
# Digite um numero de 1 a 10043
# o numero esta abaixo
# voce esta frio
# voce tem 8 vidas
# Digite um numero de 1 a 10032
# o numero esta abaixo
# voce esta quente
# voce tem 7 vidas
# Digite um numero de 1 a 10030
# o numero esta abaixo
# voce esta quente
# voce tem 6 vidas
# Digite um numero de 1 a 10027
# voce tem 5 vidas
# parabens voce acertou
# voce tentou 5 vezes
